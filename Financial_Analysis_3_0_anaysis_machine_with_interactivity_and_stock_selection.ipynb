# %% [markdown]
# <a href="https://colab.research.google.com/github/isaiahsthomas/Time-Series-Analysis-Financial-Data/blob/main/Financial_Analysis_3_0_anaysis_machine_with_interactivity_and_stock_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install yfinance
import yfinance as yf
import matplotlib as mpt
import pandas_datareader as pdr
import numpy as np
# Out:
# ...
#      |████████████████████████████████| 63 kB 720 kB/s
# ...
#      |████████████████████████████████| 6.4 MB 38.0 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %% [markdown]
# Creat an interactive input using yfinance api that can pull stock ticker information
#
# ** In this machine only three stocks can be analyzed at once although there is no limit to how many can be implemented in practice

# %%
ChooseTickers = input()
# Out:
# AAPL MSFT D

# %% [markdown]
# Using yfinance set a variable equal to yf.Tickers(your values) and run then set df equal to variable.history(period="select period",start="select start",end="select end") I chose too use inputs for interactivity

# %%
ticktock = yf.Tickers(ChooseTickers)

# %% [markdown]
# **Time series portfolio analysis**

# %%
df = ticktock.history(period="1d",start=input(),end=input())
# Out:
# 2016-01-01
# 2022-01-01
# [*********************100%***********************]  3 of 3 completed

# %%
df
# Out:
#                  Close                        Dividends                  High  \
#                   AAPL          D        MSFT      AAPL    D MSFT        AAPL
# Date
# 2016-01-04   24.185043  52.294174   49.373718       0.0  0.0  0.0   24.189636
# 2016-01-05   23.578979  52.743725   49.598980       0.0  0.0  0.0   24.299824
# 2016-01-06   23.117550  53.069260   48.697994       0.0  0.0  0.0   23.500931
# 2016-01-07   22.141886  53.100254   47.004150       0.0  0.0  0.0   22.986698
# 2016-01-08   22.258965  53.883083   47.148308       0.0  0.0  0.0   22.752537
# ...                ...        ...         ...       ...  ...  ...         ...
# 2021-12-27  179.836319  76.784752  340.949280       0.0  0.0  0.0  179.926069
# 2021-12-28  178.799164  77.260757  339.754517       0.0  0.0  0.0  180.833588
# 2021-12-29  178.888916  77.766502  340.451477       0.0  0.0  0.0  180.135494
# 2021-12-30  177.712143  77.816086  337.833008       0.0  0.0  0.0  180.075665
# ...

# %% [markdown]
# Visualize all available data in df with subplots

# %%
df.plot(figsize =(20,20),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f19edb93490>,
# ...
#       dtype=object)

# %%
df.head()
# Out:
#                 Close                       Dividends                 High  \
#                  AAPL          D       MSFT      AAPL    D MSFT       AAPL
# Date
# 2016-01-04  24.185043  52.294174  49.373718       0.0  0.0  0.0  24.189636
# 2016-01-05  23.578979  52.743725  49.598980       0.0  0.0  0.0  24.299824
# 2016-01-06  23.117550  53.069260  48.697994       0.0  0.0  0.0  23.500931
# 2016-01-07  22.141886  53.100254  47.004150       0.0  0.0  0.0  22.986698
# 2016-01-08  22.258965  53.883083  47.148308       0.0  0.0  0.0  22.752537
#
#                                         Low  ...                  Open  \
#                     D       MSFT       AAPL  ...       MSFT       AAPL
# Date                                         ...
# 2016-01-04  52.325178  49.373718  23.415989  ...  48.103336  23.556026
# 2016-01-05  52.797980  49.905313  23.510110  ...  49.139481  24.276868
# 2016-01-06  53.379290  49.013339  22.927009  ...  48.328592  23.085410
# ...

# %% [markdown]
# Seperate closing stock price values from overall df dataset for further examination

# %%
closedata = pd.DataFrame(df['Close'])

# %%
closedata.plot(figsize=(12,12),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f19ecd6ed10>,
# ...
#       dtype=object)

# %% [markdown]
# Take column name values and build list in order to reference specific columns in later analysis

# %%
columnnames = closedata.columns.values.tolist()

# %%
percent_change_col1 = closedata[columnnames[0]]/(closedata[columnnames[0]].shift(1)-1)

# %% [markdown]
# Examine volatility of each stock relative to one another based of percent change in price over selected period

# %%
percent_change_col1.plot(figsize = (12,12))

# %%
percent_change_col1 = closedata[columnnames[0]]/(closedata[columnnames[0]].shift(1)-1)

# %%
percent_change_col2 = closedata[columnnames[1]]/(closedata[columnnames[1]].shift(1)-1)

# %%
percent_change_col2.plot(figsize=(12,12))

# %%
percent_change_col3 = closedata[columnnames[2]]/(closedata[columnnames[2]].shift(1)-1)

# %%
percent_change_col3.plot(figsize=(12,12))

# %% [markdown]
# Examine density plot for any major outlier values

# %%
percent_change_col1.plot.density(figsize=(12,12))

# %%
percent_change_col2.plot.density(figsize=(12,12))

# %%
percent_change_col3.plot.density(figsize=(12,12))

# %% [markdown]
# Get return percentage data for each stock

# %%
def getreturndata(datfra):
  returninfo = []

  for nums in closedata[columnnames[0]]:
    divisor = len(closedata)-1
    nums = closedata.iloc[0]
    growthrate = (closedata.iloc[divisor]-nums)/nums

    returninfo.append(growthrate)
    return pd.DataFrame(returninfo)

# %%
growthrate = getreturndata(closedata)
growthrate
# Out:
#        AAPL         D     MSFT
# 0  6.322041  0.489752  5.78187

# %%
growthrate.plot.barh()

# %% [markdown]
# **In this section put notes or add to the code**
