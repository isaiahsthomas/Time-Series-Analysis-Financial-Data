# %% [markdown]
# <a href="https://colab.research.google.com/github/isaiahsthomas/Time-Series-Analysis-Financial-Data/blob/main/Financial_Analysis_3_0_anaysis_machine_with_interactivity_and_stock_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install yfinance
import yfinance as yf
import matplotlib as mpt
import pandas_datareader as pdr
import numpy as np
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)

# %%
ChooseTickers = input()
# Out:
# MSFT TSLA D

# %%
ticktock = yf.Tickers(ChooseTickers)

# %% [markdown]
# **Time series portfolio analysis**

# %%
df = ticktock.history(period="1d",start=input(),end=input())
# Out:
# 2015-01-01
# 2022-01-01
# [*********************100%***********************]  3 of 3 completed

# %%
df
# Out:
#                 Close                          Dividends                 High  \
#                     D        MSFT         TSLA         D MSFT TSLA          D
# Date
# 2015-01-02  57.902161   41.013309    43.862000       0.0  0.0    0  57.984355
# 2015-01-05  57.199768   40.636158    42.018002       0.0  0.0    0  57.984347
# 2015-01-06  56.908344   40.039734    42.256001       0.0  0.0    0  58.238397
# 2015-01-07  57.139973   40.548450    42.189999       0.0  0.0    0  57.543473
# 2015-01-08  57.812481   41.741318    42.124001       0.0  0.0    0  58.088949
# ...               ...         ...          ...       ...  ...  ...        ...
# 2021-12-27  76.784752  340.949280  1093.939941       0.0  0.0    0  76.943415
# 2021-12-28  77.260757  339.754517  1088.469971       0.0  0.0    0  77.369834
# 2021-12-29  77.766502  340.451477  1086.189941       0.0  0.0    0  77.885505
# 2021-12-30  77.816086  337.833008  1070.339966       0.0  0.0    0  78.024335
# 2021-12-31  77.905334  334.846161  1056.780029       0.0  0.0    0  78.163170
#
#                                            Low  ...                    Open  \
#                   MSFT         TSLA          D  ...         TSLA          D
# Date                                            ...
# 2015-01-02   41.592197    44.650002  57.184829  ...    42.652000  57.730303
# 2015-01-05   40.986997    43.299999  57.012963  ...    41.431999  57.745236
# 2015-01-06   41.004545    42.840000  56.811202  ...    40.841999  57.379091
# 2015-01-07   40.750184    42.956001  56.579557  ...    41.956001  57.065252
# 2015-01-08   41.881654    42.759998  57.446339  ...    42.001999  57.580839
# ...                ...          ...        ...  ...          ...        ...
# 2021-12-27  340.979147  1117.000000  76.378165  ...  1070.719971  76.814501
# 2021-12-28  342.303295  1119.000000  76.784754  ...  1078.420044  76.784754
# 2021-12-29  342.791154  1104.000000  77.201253  ...  1064.140015  77.350004
# 2021-12-30  341.626309  1095.550049  77.330171  ...  1053.150024  77.915251
# 2021-12-31  337.872817  1082.000000  77.330174  ...  1054.589966  77.697085
#
#                                     Stock Splits             Volume            \
#                   MSFT         TSLA            D MSFT TSLA        D      MSFT
# Date
# 2015-01-02   40.925601    44.574001            0    0  0.0  2210200  27913900
# 2015-01-05   40.671240    42.910000            0    0  0.0  2779200  39673900
# 2015-01-06   40.680018    42.012001            0    0  0.0  3290000  36447900
# 2015-01-07   40.329175    42.669998            0    0  0.0  2908100  29114100
# 2015-01-08   41.004551    42.562000            0    0  0.0  2164100  29645200
# ...                ...          ...          ...  ...  ...      ...       ...
# 2021-12-27  333.989892  1073.670044            0    0  0.0  1430700  19947000
# 2021-12-28  341.646184  1109.489990            0    0  0.0  1236100  15661500
# 2021-12-29  339.804301  1098.640015            0    0  0.0  1517900  15042000
# 2021-12-30  340.411654  1061.329956            0    0  0.0  1752300  15994500
# 2021-12-31  337.026566  1073.439941            0    0  0.0  1975500  18000800
#
#
#                 TSLA
# Date
# 2015-01-02  23822000
# 2015-01-05  26842500
# 2015-01-06  31309500
# 2015-01-07  14842000
# 2015-01-08  17212500
# ...              ...
# 2021-12-27  23715300
# 2021-12-28  20108000
# 2021-12-29  18718000
# 2021-12-30  15680300
# 2021-12-31  13577900
#
# [1763 rows x 21 columns]

# %%
df.plot(figsize =(20,20),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc1246290>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc01c6790>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc1246890>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc01a4dd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0130150>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0168490>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc011f750>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc00d79d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc00d7a10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc1478c50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0191510>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0043390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc14b0f10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc152d8d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc156de10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc15b1810>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc15f37d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc1635890>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc1677990>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc16b8810>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc16fa690>],
#       dtype=object)

# %%
df.head()
# Out:
#                 Close                       Dividends                 High  \
#                     D       MSFT       TSLA         D MSFT TSLA          D
# Date
# 2015-01-02  57.902161  41.013309  43.862000       0.0  0.0    0  57.984355
# 2015-01-05  57.199768  40.636158  42.018002       0.0  0.0    0  57.984347
# 2015-01-06  56.908344  40.039734  42.256001       0.0  0.0    0  58.238397
# 2015-01-07  57.139973  40.548450  42.189999       0.0  0.0    0  57.543473
# 2015-01-08  57.812481  41.741318  42.124001       0.0  0.0    0  58.088949
#
#                                         Low  ...                  Open  \
#                  MSFT       TSLA          D  ...       TSLA          D
# Date                                         ...
# 2015-01-02  41.592197  44.650002  57.184829  ...  42.652000  57.730303
# 2015-01-05  40.986997  43.299999  57.012963  ...  41.431999  57.745236
# 2015-01-06  41.004545  42.840000  56.811202  ...  40.841999  57.379091
# 2015-01-07  40.750184  42.956001  56.579557  ...  41.956001  57.065252
# 2015-01-08  41.881654  42.759998  57.446339  ...  42.001999  57.580839
#
#                                  Stock Splits             Volume            \
#                  MSFT       TSLA            D MSFT TSLA        D      MSFT
# Date
# 2015-01-02  40.925601  44.574001            0    0  0.0  2210200  27913900
# 2015-01-05  40.671240  42.910000            0    0  0.0  2779200  39673900
# 2015-01-06  40.680018  42.012001            0    0  0.0  3290000  36447900
# 2015-01-07  40.329175  42.669998            0    0  0.0  2908100  29114100
# 2015-01-08  41.004551  42.562000            0    0  0.0  2164100  29645200
#
#
#                 TSLA
# Date
# 2015-01-02  23822000
# 2015-01-05  26842500
# 2015-01-06  31309500
# 2015-01-07  14842000
# 2015-01-08  17212500
#
# [5 rows x 21 columns]

# %%
closedata = pd.DataFrame(df['Close'])

# %%
closedata.plot(figsize=(12,12),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bbfd6a7d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bbfd07890>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bbfd6a790>],
#       dtype=object)

# %%
columnnames = closedata.columns.values.tolist()

# %%
percent_change_col1 = closedata[columnnames[0]]/(closedata[columnnames[0]].shift(1)-1)

# %%
percent_change_col1.plot(figsize = (12,12))

# %%
percent_change_col1 = closedata[columnnames[0]]/(closedata[columnnames[0]].shift(1)-1)

# %%
percent_change_col2 = closedata[columnnames[1]]/(closedata[columnnames[1]].shift(1)-1)

# %%
percent_change_col2.plot(figsize=(12,12))

# %%
percent_change_col3 = closedata[columnnames[2]]/(closedata[columnnames[2]].shift(1)-1)

# %%
percent_change_col3.plot(figsize=(12,12))

# %%
percent_change_col1.plot.density(figsize=(12,12))

# %%
percent_change_col2.plot.density(figsize=(12,12))

# %%
percent_change_col3.plot.density(figsize=(12,12))

# %%
Return_data = pd.DataFrame(df["Close"])

# %%
def getreturndata(datfra):
  returninfo = []

  for nums in closedata[columnnames[0]]:
    divisor = len(closedata)-1
    nums = closedata.iloc[0]
    growthrate = (closedata.iloc[divisor]-nums)/nums

    returninfo.append(growthrate)
    return pd.DataFrame(returninfo)

# %%
growthrate = getreturndata(closedata)

# %%
growthrate.plot.barh()

# %% [markdown]
# **In this section put notes or add to the code**
